# %%
import json
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load Data #
df_crashes = gpd.read_file('data/crash_clusters.geojson')
df_videos = gpd.read_file('data/video_counts.geojson')
matches = pd.read_csv('data/merged_videos_labels.csv')

# %%
# Insert id variable #
matches.insert(0, 'id', range(1, 1+len(matches)))
df_videos.insert(0, 'id', range(1, 1+len(df_videos)))

# %%
# Merge Matches data in Video data #
merged = df_videos.merge(matches, on='id')

# %%
# Plots complete maps, with or without roads depending on the chosen option #
def plot_map(roads,fig_size,base_color,base_size,crash_color,crash_size,segment_color,segment_size):  
    
    if roads == True:
        n_roads = gpd.read_file('data/nairobi_roads_2010.geojson')
        base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
        df_crashes.plot(ax=base, color=crash_color, markersize=crash_size);
        df_videos.plot(ax=base, color=segment_color, markersize=segment_size);
        plt.savefig('Nairobi_map_roads.png')
        plt.close()
        
        return print('Generated map with roads!')
        
    elif roads == False:
        n_roads = gpd.read_file('data/nairobi_map.json')
        base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
        df_crashes.plot(ax=base, color=crash_color, markersize=crash_size);
        df_videos.plot(ax=base, color=segment_color, markersize=segment_size);
        plt.savefig('Nairobi_map.png')
        plt.close()
        
        return print('Generated map without roads!')

# Plots single segment maps and associated hotspot(s) if any, with or without roads depending on the chosen option #
def plot_single(segment_id,roads,fig_size,base_color,base_size,crash_color,crash_size,segment_color,segment_size):   
    
    # Segment info #
    segment = merged.loc[merged['id'] == segment_id]
    hotspots = []
    
    # Plot only the segment if no hotspots are associated with it #
    if segment['1st Hotspot Id'].values[0] == 0:

        if roads == True:
            n_roads = gpd.read_file('data/nairobi_roads_2010.geojson')
            base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
            segment.plot(ax=base, color=segment_color, markersize=segment_size);
            plt.savefig('single_segment_maps/segment_'+str(segment_id)+'_roads_0H.png');
            plt.close()

            return print('Generated 0-Hotspots single segment plot with roads!')

        elif roads == False:
            n_roads = gpd.read_file('data/nairobi_map.json')
            base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
            segment.plot(ax=base, color=segment_color, markersize=segment_size);
            plt.savefig('single_segment_maps/segment_'+str(segment_id)+'_0H.png')
            plt.close()

            return print('Generated 0-Hotspots single segment plot without roads!')

    # Else, retrieve associated hotspots info #    
    elif segment['1st Hotspot Id'].values[0] > 0:  
            hotspots = df_crashes.loc[df_crashes['id'] == segment['1st Hotspot Id'].values[0]]
            if segment['2nd Hotspot Id'].values[0] > 0:
                hotspots = hotspots.append(df_crashes.loc[df_crashes['id'] == segment['2nd Hotspot Id'].values[0]])
                if segment['3rd Hotspot Id'].values[0] > 0:
                    hotspots = hotspots.append(df_crashes.loc[df_crashes['id'] == segment['3rd Hotspot Id'].values[0]])
                    if segment['4th Hotspot Id'].values[0] > 0:
                        hotspots = hotspots.append(df_crashes.loc[df_crashes['id'] == segment['4th Hotspot Id'].values[0]])
                        if segment['5th Hotspot Id'].values[0] > 0:
                            hotspots = hotspots.append(df_crashes.loc[df_crashes['id'] == segment['5th Hotspot Id'].values[0]])
                            if segment['6th Hotspot Id'].values[0] > 0:
                                hotspots = hotspots.append(df_crashes.loc[df_crashes['id'] == segment['6th Hotspot Id'].values[0]])


            # Plot the segment and the associated hotspots #                          
            if roads == True:
                n_roads = gpd.read_file('data/nairobi_roads_2010.geojson')
                base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
                segment.plot(ax=base, color=segment_color, markersize=segment_size);
                hotspots.plot(ax=base, color=crash_color, markersize=crash_size);
                plt.savefig('single_segment_maps/segment_'+str(segment_id)+'_roads_'+str(len(hotspots))+'H.png');
                plt.close()

                return print('Generated '+str(len(hotspots))+'-Hotspots single segment plot with roads!')

            elif roads == False:
                n_roads = gpd.read_file('data/nairobi_map.json')
                base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
                segment.plot(ax=base, color=segment_color, markersize=segment_size);
                hotspots.plot(ax=base, color=crash_color, markersize=crash_size);
                plt.savefig('single_segment_maps/segment_'+str(segment_id)+'_'+str(len(hotspots))+'H.png')
                plt.close()

                return print('Generated '+str(len(hotspots))+'-Hotspots single segment plot without roads!')

# %%
plot_map(roads=False,fig_size=200,base_color='black', 
         base_size=1,crash_color='r',crash_size=15,segment_color='b',segment_size=15)
# Out:
# Generated map without roads!

# %%
for i in range(129,len(df_videos)):
    print('Printing Map of Segment '+str(i+1))
    plot_single(segment_id=i+1,roads=False,fig_size=100,base_color='black', 
    base_size=1,crash_color='r',crash_size=15,segment_color='b',segment_size=15)
# Out:
# Printing Map of Segment 130
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 131
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 132
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 133
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 134
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 135
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 136
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 137
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 138
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 139
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 140
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 141
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 142
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 143
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 144
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 145
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 146
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 147
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 148
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 149
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 150
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 151
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 152
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 153
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 154
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 155
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 156
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 157
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 158
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 159
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 160
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 161
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 162
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 163
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 164
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 165
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 166
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 167
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 168
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 169
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 170
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 171
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 172
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 173
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 174
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 175
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 176
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 177
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 178
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 179
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 180
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 181
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 182
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 183
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 184
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 185
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 186
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 187
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 188
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 189
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 190
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 191
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 192
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 193
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 194
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 195
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 196
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 197
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 198
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 199
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 200
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 201
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 202
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 203
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 204
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 205
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 206
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 207
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 208
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 209
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 210
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 211
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 212
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 213
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 214
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 215
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 216
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 217
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 218
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 219
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 220
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 221
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 222
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 223
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 224
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 225
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 226
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 227
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 228
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 229
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 230
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 231
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 232
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 233
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 234
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 235
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 236
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 237
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 238
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 239
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 240
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 241
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 242
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 243
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 244
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 245
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 246
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 247
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 248
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 249
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 250
# Generated 3-Hotspots single segment plot without roads!
# Printing Map of Segment 251
# Generated 5-Hotspots single segment plot without roads!
# Printing Map of Segment 252
# Generated 5-Hotspots single segment plot without roads!
# Printing Map of Segment 253
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 254
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 255
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 256
# Generated 4-Hotspots single segment plot without roads!
# Printing Map of Segment 257
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 258
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 259
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 260
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 261
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 262
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 263
# Generated 2-Hotspots single segment plot without roads!
# Printing Map of Segment 264
# Generated 1-Hotspots single segment plot without roads!
# Printing Map of Segment 265
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-b555c996ee91> in <module>
#       2     print('Printing Map of Segment '+str(i+1))
#       3     plot_single(segment_id=i+1,roads=False,fig_size=100,base_color='black',
# ----> 4     base_size=1,crash_color='r',crash_size=15,segment_color='b',segment_size=15)
#       5
#
# <ipython-input-5-b3372ae2819b> in plot_single(segment_id, roads, fig_size, base_color, base_size, crash_color, crash_size, segment_color, segment_size)
#      78             elif roads == False:
#      79                 n_roads = gpd.read_file('data/nairobi_map.json')
# ---> 80                 base = n_roads.plot(color=base_color,markersize=base_size,figsize=(fig_size,fig_size));
#      81                 segment.plot(ax=base, color=segment_color, markersize=segment_size);
#      82                 hotspots.plot(ax=base, color=crash_color, markersize=crash_size);
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     604         from there.
#     605         """
# --> 606         return plot_dataframe(self, *args, **kwargs)
#     607
#     608     plot.__doc__ = plot_dataframe.__doc__
#
# ~\Anaconda3\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, classification_kwds, **style_kwds)
#     500             figsize=figsize,
#     501             markersize=markersize,
# --> 502             **style_kwds
#     503         )
#     504
#
# ~\Anaconda3\lib\site-packages\geopandas\plotting.py in plot_series(s, cmap, color, ax, figsize, **style_kwds)
#     356         plot_point_collection(ax, points, values_, color=color, cmap=cmap, **style_kwds)
#     357
# --> 358     plt.draw()
#     359     return ax
#     360
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in draw()
#     714         fig.canvas.draw_idle()
#     715     """
# --> 716     get_current_fig_manager().canvas.draw_idle()
#     717
#     718
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     384         Draw the figure using the renderer.
#     385         """
# --> 386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
#     388             self.figure.draw(self.renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     397                           and getattr(self, "_lastKey", None) == key)
#     398         if not reuse_renderer:
# --> 399             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     400             self._lastKey = key
#     401         elif cleared:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      84         self.width = width
#      85         self.height = height
# ---> 86         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      87         self._filter_renderers = []
#      88
#
# MemoryError: In RendererAgg: Out of memory
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     384         Draw the figure using the renderer.
#     385         """
# --> 386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
#     388             self.figure.draw(self.renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     397                           and getattr(self, "_lastKey", None) == key)
#     398         if not reuse_renderer:
# --> 399             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     400             self._lastKey = key
#     401         elif cleared:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      84         self.width = width
#      85         self.height = height
# ---> 86         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      87         self._filter_renderers = []
#      88
#
# MemoryError: In RendererAgg: Out of memory
